# %%
import matplotlib.pyplot as plt

# %%
HR_data_y = [0.8589443343541704, 0.8888488560619708, 0.8920915150423347, 0.8899297423887588,0.8929922536479914]
NDCG_data_y = [0.6068693733553174, 0.6685710965734314, 0.6668575479566532, 0.6676215549837085,0.6788677319195672]

# %%
plt.title("HR@10 - 2 Hop")
plt.xlim(18,102)
plt.ylim(0.7, 0.9) 
plt.plot([20, 40, 60, 80, 100], HR_data_y, marker='o')
plt.savefig("hr10.png")

# %%
plt.title("NDCG@10 - 2 Hop")
plt.xlim(18,102)
plt.ylim(0.45, 0.69)
plt.plot([20, 40, 60, 80, 100], NDCG_data_y, marker='o')
plt.savefig("ndcg10.png")
